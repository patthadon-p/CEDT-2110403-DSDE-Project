# %% [markdown]
# # Data Scrapping

# %% [markdown]
# ## Import necessary libraries

# %%
# %pip install -qq -r ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Add current directory to Python path for imports
import os
import sys

# Add the parent directory (project root) to Python path so we can import from src
project_root = os.path.dirname(os.getcwd())
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Scraping Population Data

# %%
from src.scrapping import PopulationScrapping

# Scrape population
scraper = PopulationScrapping()
population_df = scraper.fetch_and_clean()
population_df.head(10)
# Out:
#   RCODE-DESC      CCAATT-DESC  TOTAL  HOUSE
# 0     พระนคร  พระบรมมหาราชวัง  2,884  1,195
# 1     พระนคร   วังบูรพาภิรมย์  8,360  5,322
# 2     พระนคร       วัดราชบพิธ  2,781    979
# 3     พระนคร      สำราญราษฎร์  2,619  1,096
# 4     พระนคร   ศาลเจ้าพ่อเสือ  2,574  1,001
# 5     พระนคร        เสาชิงช้า  1,838    698
# 6     พระนคร         บวรนิเวศ  3,440  1,577
# 7     พระนคร          ตลาดยอด  1,853  1,171
# 8     พระนคร        ชนะสงคราม  1,593    827
# 9     พระนคร        บ้านพานถม  5,269  2,002

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RCODE-DESC   180 non-null    object
#  1   CCAATT-DESC  180 non-null    object
#  2   TOTAL        180 non-null    object
#  3   HOUSE        180 non-null    object
# dtypes: object(4)
# memory usage: 5.8+ KB

# %% [markdown]
# ---
